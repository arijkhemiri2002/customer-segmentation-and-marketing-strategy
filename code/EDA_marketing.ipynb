# %% [markdown]
# ## Analyse exploratoire des données(EDA)

# %%
import pandas as pd

data = pd.read_csv("../data/marketing_campaign_EDA.csv")
data.head()
# Out:
#     Income  Recency  NumWebVisitsMonth  Education_encoded  \
# 0  58138.0       58                  7                  3
# 1  46344.0       38                  5                  3
# 2  71613.0       26                  4                  3
# 3  26646.0       26                  6                  3
# 4  58293.0       94                  5                  5
#
#    Marital_Status_encoded  Age  Seniority  TotalMnt  TotalPurchases  \
# 0                     1.0   69        165      1617              25
# 1                     1.0   72        147        27               6
# 2                     2.0   61        153       776              21
# 3                     2.0   42        147        53               8
# 4                     3.0   45        148       422              19
#
#    TotalChildren  SpendPerIncome
# 0              0        0.027813
# 1              2        0.000583
# 2              0        0.010836
# 3              1        0.001989
# 4              1        0.007239

# %% [markdown]
# # Analyse statistique

# %%
data.describe()
# Out:
#               Income      Recency  NumWebVisitsMonth  Education_encoded  \
# count    2216.000000  2216.000000        2216.000000        2216.000000
# mean    52247.251354    49.012635           5.319043           3.459838
# std     25173.076661    28.948352           2.425359           1.004825
# min      1730.000000     0.000000           0.000000           1.000000
# 25%     35303.000000    24.000000           3.000000           3.000000
# 50%     51381.500000    49.000000           6.000000           3.000000
# 75%     68522.000000    74.000000           7.000000           4.000000
# max    666666.000000    99.000000          20.000000           5.000000
#
#        Marital_Status_encoded          Age    Seniority     TotalMnt  \
# count             2213.000000  2216.000000  2216.000000  2216.000000
# mean                 2.483507    57.179603   154.637184   607.075361
# std                  1.049982    11.985554     6.766012   602.900476
# ...

# %% [markdown]
# # Analyse univariée

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

mapping = {
    1: "Primary",
    2: "Secondary",
    3: "Bachelor",
    4: "Master/PhD"
}

education_labels = data['Education_encoded'].map(mapping)
data['education_labels'] = data['Education_encoded'].map(mapping)

NUM_VARS = ["Income", "TotalMnt", "Recency", "Age",
            "TotalPurchases", "Seniority", "SpendPerIncome"]
 
CAT_VARS = ["TotalChildren","education_labels"]
COLORS = {
    "Income":         "#7F77DD",
    "TotalMnt":       "#1D9E75",
    "Recency":        "#D85A30",
    "Age":            "#BA7517",
    "TotalPurchases": "#378ADD",
    "Seniority":      "#639922",
    "SpendPerIncome": "#D4537E",
    "TotalChildren":  "#1D9E75",
    "education_labels":"#7F77DD",
}
fig, axes = plt.subplots(3, 3, figsize=(15, 12))
fig.suptitle("Distribution univariée des variables", fontsize=15, fontweight="bold", y=1.01)
 
sns.set_style("whitegrid")
plt.rcParams.update({"axes.spines.top": False, "axes.spines.right": False})
 
all_vars = NUM_VARS + CAT_VARS  # 9 variables
 
for ax, var in zip(axes.flat, all_vars):
    color = COLORS[var]
 
    if var in NUM_VARS:
        series = data[var].dropna()
        ax.hist(series, bins=30, color=color, alpha=0.55,
                edgecolor="white", linewidth=0.4, density=True)
        series.plot.kde(ax=ax, color=color, linewidth=2.2)
        ax.axvline(series.mean(),   color="black", linestyle="--",
                   linewidth=1.2, label=f"Moy: {series.mean():.1f}")
        ax.axvline(series.median(), color="gray",  linestyle=":",
                   linewidth=1.4, label=f"Méd: {series.median():.1f}")
        ax.legend(fontsize=8, framealpha=0.4)
        ax.set_title(f"{var}  (skew={series.skew():.2f})", fontsize=10, fontweight="500")
 
    elif var == "TotalChildren":
        counts = data[var].value_counts().sort_index()
        bars = ax.bar(counts.index.astype(str), counts.values,
                      color=color, alpha=0.75, edgecolor="white")
        for bar in bars:
            pct = bar.get_height() / len(data) * 100
            ax.text(bar.get_x() + bar.get_width()/2,
                    bar.get_height() + len(data)*0.005,
                    f"{pct:.1f}%", ha="center", va="bottom", fontsize=8)
        ax.set_title("TotalChildren", fontsize=10, fontweight="500")
        ax.set_xlabel("Nombre d'enfants")
 
    elif var == "education_labels":
        order = data[var].value_counts().index
        counts = data[var].value_counts()
        bars = ax.bar(range(len(order)), counts.values,
                      color=color, alpha=0.75, edgecolor="white")
        ax.set_xticks(range(len(order)))
        ax.set_xticklabels(order, rotation=20, ha="right", fontsize=8)
        for bar in bars:
            pct = bar.get_height() / len(data) * 100
            ax.text(bar.get_x() + bar.get_width()/2,
                    bar.get_height() + len(data)*0.005,
                    f"{pct:.1f}%", ha="center", va="bottom", fontsize=8)
        ax.set_title("Education", fontsize=10, fontweight="500")
 
    ax.set_ylabel("Densité" if var in NUM_VARS else "Clients", fontsize=8)
    ax.tick_params(labelsize=8)
    ax.set_facecolor("#f9f9f9")
 
plt.tight_layout()
plt.savefig("distributions_univariees.png", dpi=150, bbox_inches="tight")
plt.show()

# %% [markdown]
# # Analyse bivariée

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Création de la figure avec 1 ligne et 3 colonnes
plt.figure(figsize=(18,5))

#  1. Income vs TotalMnt
plt.subplot(1,3,1)
sns.scatterplot(x="Income", y="TotalMnt", data=data, hue="TotalChildren")
plt.title("Income vs TotalMnt")

#  2. Age vs TotalPurchases
plt.subplot(1,3,2)
sns.scatterplot(x="Age", y="TotalPurchases", data=data, hue="TotalChildren")
plt.title("Age vs TotalPurchases")

#  3. Recency vs TotalMnt
plt.subplot(1,3,3)
sns.scatterplot(x="Recency", y="TotalMnt", data=data, hue="TotalChildren")
plt.title("Recency vs TotalMnt")

# Ajustement automatique
plt.tight_layout()

# Affichage
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Style propre
sns.set(style="whitegrid")

# Création figure
plt.figure(figsize=(18,5))

# 🔹 1. TotalMnt par Education
plt.subplot(1,3,1)
sns.boxplot(x="education_labels", y="TotalMnt", data=data)
plt.title("TotalMnt par Education")

mapping = {1:"Single", 2:"Together", 3:"Married", 4:"Divorced",5:"Widow",0:"Other"}
data["Marital_Status"] = data["Marital_Status_encoded"].map(mapping)
# 🔹 2. Income par Marital Status
plt.subplot(1,3,2)
sns.boxplot(x="Marital_Status", y="Income", data=data)
plt.title("Income par Marital Status")

# 🔹 3. TotalPurchases par Education
plt.subplot(1,3,3)
sns.boxplot(x="education_labels", y="TotalPurchases", data=data)
plt.title("TotalPurchases par Education")

# Ajustement
plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

plt.figure(figsize=(18,5))

# 🔹 1. TotalChildren vs TotalMnt
plt.subplot(1,3,1)
sns.boxplot(x="TotalChildren", y="TotalMnt", data=data)
plt.title("TotalChildren vs TotalMnt")

# 🔹 2. Kidhome vs NumWebVisitsMont
plt.subplot(1,3,2)
sns.boxplot(x="TotalChildren", y="NumWebVisitsMonth", data=data)
plt.title("KidhTotalChildren vs NumWebVisitsMonth")

# 🔹 3. Teenhome vs TotalPurchases
plt.subplot(1,3,3)
sns.boxplot(x="TotalChildren", y="TotalPurchases", data=data)
plt.title("TotalChildren vs TotalPurchases")

plt.tight_layout()
plt.show()

# %%
import numpy as np
#matrice de corrélation
NUM_ALL = ["Income","TotalMnt","Recency","Age","TotalPurchases",
           "Seniority","SpendPerIncome","Kidhome","Teenhome",
           "TotalChildren","NumWebVisitsMont","Education_encoded","Marital_Status_encoded"] 
corr_cols = [c for c in NUM_ALL if c in data.columns]
corr_matrix = data[corr_cols].corr()
 
fig, ax = plt.subplots(figsize=(14, 11))
 
mask = np.triu(np.ones_like(corr_matrix, dtype=bool), k=1)  
 
sns.heatmap(
    corr_matrix,
    mask=mask,
    annot=True,
    fmt=".2f",
    cmap="RdYlGn",
    center=0,
    vmin=-1, vmax=1,
    linewidths=0.4,
    linecolor="white",
    annot_kws={"size": 7},
    ax=ax,
    cbar_kws={"shrink": 0.7, "label": "Coefficient de corrélation"}
)
 
ax.set_title("Heatmap de corrélation — toutes variables numériques",
             fontsize=13, fontweight="bold", pad=14)
ax.tick_params(axis="x", rotation=40, labelsize=8)
ax.tick_params(axis="y", rotation=0,  labelsize=8)
